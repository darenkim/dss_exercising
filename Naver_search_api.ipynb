# %%
import os
import sys
import urllib.request
client_id = "YZC6SeBFdwM_W4bz0LJv"
client_secret = "na04zS1A1F"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# %%
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 29 Oct 2020 20:31:55 +0900",
# "total": 180211,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> 학원 집중해야 할 포인트",
# "link": "https:\/\/blog.naver.com\/km_y?Redirect=Log&logNo=222122522937",
# "description": "1학년 필수 교양을 먼저 배우는 것이 낫겠다 싶어 <b>파이썬</b> 학원을 다니고자 결정을 내릴 수 있었던... 그렇게 <b>파이썬</b> 학원에 등록을 하고 배우기 시작했어요. 아, 제가 배우면서 가장 좋았던 점은 처음 상담을... ",
# "bloggername": "김과장 블로그",
# "bloggerlink": "https://blog.naver.com/km_y",
# "postdate": "20201021"
#
# },
# {
# "title": "<b>파이썬</b>(Phython)이 스타트업에게 인기있는 이유 7가지",
# "link": "http://blog.wishket.com/%ED%8C%8C%EC%9D%B4%EC%8D%ACpython%EC%9D%B4-%EC%8A%A4%ED%83%80%ED%8A%B8%EC%97%85%EC%97%90%EA%B2%8C-%EC%9D%B8%EA%B8%B0%EC%9E%88%EB%8A%94-%EC%9D%B4%EC%9C%A0-7%EA%B0%80%EC%A7%80/",
# "description": "<b>파이썬</b>(Python)이 스타트업에게 인기있는 이유 7가지 Facebook Twitter 안녕하세요. 위시켓입니다.... 그렇기 때문에 <b>파이썬</b>(Python)과 같은 강력하면서도 기반이 튼튼한 기술을 사용하는 것이 가장 좋습니다.... ",
# "bloggername": "Wishket",
# ...

# %%
import os
import sys
import urllib.request
client_id = "YZC6SeBFdwM_W4bz0LJv"
client_secret = "na04zS1A1F"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# %%
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 29 Oct 2020 20:31:55 +0900",
# "total": 1141,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드, C/C++, 자바 코드 제공)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16439154",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928",
# "author": "나동빈",
# "price": "34000",
# "discount": "30600",
# "publisher": "한빛미디어",
# "pubdate": "20200805",
# "isbn": "1162243074 9791162243077",
# "description": "8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다."
#
# },
# {
# "title": "<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16406247",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/062/16406247.jpg?type=m1&udate=20201028",
# ...

# %%
import os
import sys
import urllib.request
client_id = "YZC6SeBFdwM_W4bz0LJv"
client_secret = "na04zS1A1F"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# %%
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 29 Oct 2020 20:31:56 +0900",
# "total": 206553,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "[숑부티크] 32타입 A라인 프린트 나염 실키 롱스커트 / 실크 새틴 플라워 플로럴 꽃나염 블루 에메랄드 데이지 튤립 페인팅 뱀피 <b>파이톤</b> 호피 레오파드 도트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82419205697",
# "image": "https://shopping-phinf.pstatic.net/main_8241920/82419205697.6.jpg",
# "lprice": "18500",
# "hprice": "0",
# "mallName": "숑숑150",
# "productId": "82419205697",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "패션의류",
# "category2": "여성의류",
# "category3": "스커트",
# "category4": ""
#
# },
# {
# "title": "국내제작 미니 반달 투웨이 숄더 크로스 호보백",
# "link": "https://search.shopping.naver.com/gate.nhn?id=22883016920",
# "image": "https://shopping-phinf.pstatic.net/main_2288301/22883016920.20200517143913.jpg",
# "lprice": "16600",
# "hprice": "17000",
# "mallName": "네이버",
# "productId": "22883016920",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "패션잡화",
# ...

# %%
import os
import sys
import urllib.request
client_id = "YZC6SeBFdwM_W4bz0LJv"
client_secret = "na04zS1A1F"
encText = urllib.parse.quote("몰스킨")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Thu, 29 Oct 2020 20:31:56 +0900",
# "total": 38695,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>몰스킨</b> <b>몰스킨</b> 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24014109279",
# "image": "https://shopping-phinf.pstatic.net/main_2401410/24014109279.20200903005345.jpg",
# "lprice": "21130",
# "hprice": "49640",
# "mallName": "네이버",
# "productId": "24014109279",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기업 각인",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82635708485",
# "image": "https://shopping-phinf.pstatic.net/main_8263570/82635708485.jpg",
# "lprice": "24100",
# "hprice": "0",
# "mallName": "에코펜",
# "productId": "82635708485",
# "productType": "2",
# "brand": "몰스킨",
# "maker": "몰스킨",
# ...

# %%
def gen_search_url(api_node, search_text, start_num,disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = '/' + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start='&start=' + str(start_num)
    param_disp = '&display=' + str(disp_num)
    
    return base+node+param_query + param_start + param_disp

# %%
gen_search_url('shop', 'Test', 10,3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=Test&start=10&display=3'

# %%
import json
import datetime

def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    
    print("[%s] Url Request Success" % datetime.datetime.now())
    
    return json.loads(response.read().decode('utf-8'))

# %%
client_id = "YZC6SeBFdwM_W4bz0LJv"
client_secret = "na04zS1A1F"

url = gen_search_url('shop', '몰스킨', 1, 5)
one_result = get_result_onpage(url)

one_result
# Out:
# [2020-10-29 20:31:57.905285] Url Request Success
# {'lastBuildDate': 'Thu, 29 Oct 2020 20:31:57 +0900',
#  'total': 38695,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '<b>몰스킨</b> <b>몰스킨</b> 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24014109279',
#    'image': 'https://shopping-phinf.pstatic.net/main_2401410/24014109279.20200903005345.jpg',
#    'lprice': '21130',
#    'hprice': '49640',
#    'mallName': '네이버',
#    'productId': '24014109279',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기업 각인',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=82635708485',
#    'image': 'https://shopping-phinf.pstatic.net/main_8263570/82635708485.jpg',
#    'lprice': '24100',
#    'hprice': '0',
#    'mallName': '에코펜',
# ...

# %%
one_result['items'][0]['title']
# Out:
# '<b>몰스킨</b> <b>몰스킨</b> 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루'

# %%
one_result['items'][0]['lprice']
# Out:
# '21130'

# %%
one_result['items'][0]['mallName']
# Out:
# '네이버'

# %%
import pandas as pd

def get_field(json_data):
    
    title = [each['title'] for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    
    result_pd = pd.DataFrame({'title': title, 'lprice' : lprice, 'hprice' : hprice, 'link':link\
                            ,'mall': mall_name})
    
    return result_pd

# %%
get_field(one_result)
# Out:
#                                                title lprice hprice  \
# 0  <b>몰스킨</b> <b>몰스킨</b> 2021 데일리 12M 다이어리 소프트커버 ...  21130  49640
# 1  <b>몰스킨</b> 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업...  24100      0
# 2                          <b>몰스킨</b> 클래식노트 플레인 하드 L  17560  59400
# 3                       <b>몰스킨</b> 클래식노트 플레인 W.그린 하드  17560  36900
# 4        한정판 <b>몰스킨</b> 2021 어린왕자 데일리 12M 다이어리 하드 포켓  30146  35800
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 2  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
def get_field(json_data):
    
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    
    result_pd = pd.DataFrame({'title': title, 'lprice' : lprice, 'hprice' : hprice, 'link':link\
                            ,'mall': mall_name})
    
    return result_pd

# %%
url = gen_search_url('shop', '몰스킨', 1, 5)
json_result = get_result_onpage(url)
pd_result= get_field(json_result)
# Out:
# [2020-10-29 20:31:58.892297] Url Request Success

# %%
pd_result
# Out:
#                                                title lprice hprice  \
# 0          몰스킨 몰스킨 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루  21130  49640
# 1  몰스킨 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기...  24100      0
# 2                                 몰스킨 클래식노트 플레인 하드 L  17560  59400
# 3                              몰스킨 클래식노트 플레인 W.그린 하드  17560  36900
# 4               한정판 몰스킨 2021 어린왕자 데일리 12M 다이어리 하드 포켓  30146  35800
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 2  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
result_mol = []

for i in range(1,1000,100):
    url = gen_search_url('shop', '몰스킨', i, 100)
    json_result = get_result_onpage(url)
    pd_result= get_field(json_result)
    
    result_mol.append(pd_result)
    
    
result_mol = pd.concat(result_mol)
# Out:
# [2020-10-29 20:31:59.848042] Url Request Success
# [2020-10-29 20:32:00.899846] Url Request Success
# [2020-10-29 20:32:01.945513] Url Request Success
# [2020-10-29 20:32:02.993932] Url Request Success
# [2020-10-29 20:32:04.043651] Url Request Success
# [2020-10-29 20:32:05.087695] Url Request Success
# [2020-10-29 20:32:06.137205] Url Request Success
# [2020-10-29 20:32:07.185730] Url Request Success
# [2020-10-29 20:32:08.236600] Url Request Success
# [2020-10-29 20:32:09.285521] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 46.9+ KB

# %%
result_mol.reset_index(drop=True, inplace = True)

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
result_mol.head()
# Out:
#                                                title lprice hprice  \
# 0          몰스킨 몰스킨 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루  21130  49640
# 1  몰스킨 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기...  24100      0
# 2                                 몰스킨 클래식노트 플레인 하드 L  17560  59400
# 3                              몰스킨 클래식노트 플레인 W.그린 하드  17560  36900
# 4               한정판 몰스킨 2021 어린왕자 데일리 12M 다이어리 하드 포켓  30146  35800
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 2  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
result_mol['mall'].unique()
# Out:
# array(['네이버', '에코펜', '인스월드', '소확행 몰', 'Buytop', '짱구다니몰', '쿠팡', '기프트마스터',
#        '우멍가게', '티몬', '몰스킨스토어', '위메프', 'G마켓', '스티치퓨어스티치', '11번가',
#        'Shuhei Oda', '유닛808', 'morris'], dtype=object)

# %%
result_mol['lprice'] = result_mol['lprice'].astype('object')
result_mol['hprice'] = result_mol['hprice'].astype('object')

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
rc('font', family = 'NanumGothic')

# %%
plt.figure(figsize=(15,6))

sns.countplot('mall', data = result_mol, palette = 'RdYlGn', order = result_mol['mall'].value_counts().index)

plt.xticks(rotation = 90)
plt.show();
# Out:
# /Users/gyeonghankim/opt/anaconda3/envs/dss20/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_mol['mall'].value_counts().index
# Out:
# Index(['네이버', '티몬', '쿠팡', '유닛808', '몰스킨스토어', '위메프', '에코펜', 'morris', '소확행 몰',
#        '우멍가게', 'G마켓', '11번가', '인스월드', '기프트마스터', '스티치퓨어스티치', 'Buytop',
#        'Shuhei Oda', '짱구다니몰'],
#       dtype='object')
